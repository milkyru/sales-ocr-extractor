# %%
import pytesseract
import cv2

def test_basic_ocr():
    try:
        # Test if tesseract works
        version = pytesseract.get_tesseract_version()
        print(f"Tesseract version: {version}")
        
        # Test with a simple image
        image_path = input("Enter path to test image: ")
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        print("Extracted text:")
        print(text)
        
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    test_basic_ocr()
# Out:
# Tesseract version: 5.5.0.20241111
# Extracted text:
# Showroom : NOVA ( TRADEHUB 21 )
# Date : 22/0812025
# Atome/Grab/ | Paynow/Cheque
#
# Sales Order no. isa
# f=). = [= =f revesme Senet
#
# Pa ken | 4302904 | sizesag[SC~*dC SOO SSCS
#
# Walk in (W)
# Total Deposit | petum partes (ra) For Showroom Use
# Marketing (M)
#
# $700.00 [__m__|
# [a icheat | 1-s0z005 F stgene en seson pV sitanan fw
# a a Ta (a CO [$000 |_|
# CG SY C1 DL 1
# a |
# OS A A a NT (SE (ONE NN I bor” > aac
# i a sr CF 80.00
# as a A eS | se a el |
# a YS
# Pep FF $0.00 cto
# ra i or
# = ee ?
# a A | ee | ee a) Te $0.00 din
# = | a a: a RN (A 1 eal
# = oa Fe noe
# = eee
# =< a, or
# Ss
#
# ea i a a el Ra
# pe suas peas | fe 4 ar $0000" fr Teens
#
# Today's Sales
#
# Total Sales(UPitO! 645779.08 $80,312.73 $36,537.00 | $29,902.90 | $61,928.02 | $90,372.50
# Yesterday)
#
# Decosit
# Actual Total Sales
# (Up to Date) $45,719.08 $80,312.73 $37,820.49 $30,992.81 | $61,928.02 | $90,372.50 SS eS os
#
# ; TOTAL DEPOSIT AS OF YESTERDAY | seaose200 | 392.90
#
# TOTAL DEPOSIT AS OF TODAY
#
# $347,145.63
#
# $283,080.90

# %% [markdown]
# test
