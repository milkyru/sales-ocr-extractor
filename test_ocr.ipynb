# %%
import pytesseract
import cv2

def test_basic_ocr():
    try:
        # Test if tesseract works
        version = pytesseract.get_tesseract_version()
        print(f"Tesseract version: {version}")
        
        # Test with a simple image
        image_path = input("Enter path to test image: ")
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        print("Extracted text:")
        print(text)
        
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    test_basic_ocr()
# Out:
# Tesseract version: 5.5.0.20241111
# Extracted text:
# Date : 21/07/2025 (MONDAY)
#
# Showro,
# om : NOVA ( TRAD}
# a5 Catee Orderno. || ay eee EHUB 21)
# fount
# Nets
# o ZOEWE: 723026 MCNvisa x 1
# (E2 a $2,660.55 ca eerceal & 5
# |= $2,900.00 sai [oom ae
# ; { Ts280000 wT
# + [0.00 | 1
# 5 | $0.00 { 1
# z { [sooo | 1
# . {$0.00 | i
# 0.00
# 7 | T_$0.00_| =|
# es {$0.00 |
# 2 \ [- s0.00__|
# * {$0.00 —_|—
# aad {$0.00 |
# Bs {$0.00 |
# 16 {$0.00 |
# | | $0.00 |
# ia {$0.00 |
# < | s0.00 |
# - [$0.00 |
# = {$0.00 |
# 2 {$0.00
# = ! - $0.00 |
# = ‘$0.00
# {sono} <—S
# Total Deposit: $2,660.55 $0.00 $2,900.00 $0.00 $0.00 $0.00 | $2,900.00 |
# TOM JOHN KEN MICHEAL | CLAYTON | ZOEWE | | \
# Today's Sales
# $2,680.55 | | \
# Total Sales (Up to
# verona) $68,636.55 | $48,448.94 | $22,797.87 | $28,090.89 $34,569.32 | $56,096.30 | | \
# (-) Insufficient | \ \
# Deposit
# ‘Actual Total Sales asaga | $22,797.87 | $28,090.89 | $24,560.32 | $58,758.85 | \ \ \
# (Up to Date) $68,636.55 | $48, $
#
# TOTAL DEPOSIT AS OF vest#0n| $235,298.98
#
# TOTAL DEPOSIT AS OF roony|_ s2esseo8

# %% [markdown]
# test
