# %%
import pytesseract
import cv2

def test_basic_ocr():
    try:
        # Test if tesseract works
        version = pytesseract.get_tesseract_version()
        print(f"Tesseract version: {version}")
        
        # Test with a simple image
        image_path = input("Enter path to test image: ")
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        print("Extracted text:")
        print(text)
        
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    test_basic_ocr()
# Out:
# Tesseract version: 5.5.0.20241111
# Extracted text:
# Date : 2/07/2025 (WEDNESDAY)
#
# Showroom : NOVA ( TRADEHUB 21 )
#
# sm | tame | Sales Orderno. | Amount Nets AtomelGraby_ | PaynowiCh “ae
# wens Cy tee ree heel). el || pecans
# ‘ewe
# 7 |__Zoewe 4302572 |_ $1,365.14 $50.00
# 2 Tom 4-302573__ | _ $2,898.00 $1,658.62 sess R2
# 7a |EeEToR 4-302574 | _ $3,198.00 $3,485.82 $385 89 @
# be Tom 1- 485.
# d 302575 | $1,629.00__|__$1,77561 Sia7eel ie a
# : $0.00 (CashPaynow/Atome!
# ; ‘$0.00 Stee) sverei eee ony
# : $0.00 dy
# - $0.00 Ei
# $0.00 5
# 5 (Great Card Si
# 2 $0.00 Very P
# $0.00
# a $0.00
# # $0.00 in
# “ $0.00 (di Bl
# 7 $0.00 4,
# 16 $0.00 i
# # $0.00)
# = _|__John 7-302514 | Bal. Payment $354,007 | $354.00
# 0 Cur $0.00
# = WW) $0.00
# ra $0.00
# Z $0.00
# Total SR Sales
# 2 $0.00 (Up to Dato)
# Total Deposit = $9,000.14 | $1,e2561 | $5,14464 | $0.00 $0.00 $354.00 _| $7,324.25
# N MICHEAL | CLAYTON | ZOEWE
# TOM JOHN Ke oes
# Today's Sales
# $7,725.00 $1,365.14
# Total Sales (Up to] $94,140.22 | $6,446.00 | $3,183.44 | $5,491.50 | $5,631.09 | $17,918.15
# Yesterday) 5
# (© insufficient
# Deposit
# Actual Total Sales | $75,965.22 | $6,446.00 $3,183.44 | $5,491.50 | $5,631.09 | $19,269.29
# (Up to Date) 3
# TOTAL DEPOSIT AS OF YESTERDAY| ($54,791.43
#
# TOTAL DEPOSIT AS OF TODAY|
#
# $54,791.43

# %% [markdown]
# test
